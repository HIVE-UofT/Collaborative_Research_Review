# %%
! pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp312-cp312-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 18.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9

# %%
import json
import psycopg2

# Load JSON data
with open('data_canada_v1_m2.json', 'r') as file:
    json_data = json.load(file)

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="....",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()

# Insert data into the table
for record in json_data:
    cursor.execute(
        """
        INSERT INTO m2 (pid, data)
        VALUES (%s, %s::jsonb)
        """,
        (record['PID'], json.dumps(record))
    )

# Commit the transaction and close the connection
conn.commit()
cursor.close()
conn.close()
